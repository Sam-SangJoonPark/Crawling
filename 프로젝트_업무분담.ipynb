# %% [markdown]
# # 크롤링 코드분담

# %% [markdown]
# 1. 코멘트 리뷰 크롤링 <br>
# 2. 영화 검색 후 리스트 추출하는 코드<br>
#         - 제목, 출시년도&국가, 무비코드
# 3. 각 list의 element기반으로 영화 데이터를 추출하는 코드<br>
#         - 감독, 제목 & 출시년도 & 장르세트, 평점, 원제(있는것만), 평점(후순위)

# %% [markdown]
# ### 무한스크롤 링크 <br>
# ref : https://velog.io/@devmin/selenium-crawling-infinite-scroll-click

# %% [markdown]
# # 영화 검색 후 리스트를 추출하는 샘플 결과물

# %%
temp = []

# %%
temp_dict = {'Title':'해리포터와 아즈카반의 죄수',
'Release_Year':2004,
'Director':'Director'}

# %%
temp_dict2 = {'Title':'두번쨰 해리포터',
'Release_Year':2009,
'Director':'Director2'}

# %%
temp.append(temp_dict2)

# %%
temp
# Out:
# [{'Title': '해리포터와 아즈카반의 죄수', 'Release_Year': 2004, 'Director': 'Director'},
#  {'Title': '두번쨰 해리포터', 'Release_Year': 2009, 'Director': 'Director2'}]

# %%
import pandas as panda

# %%
df = panda.read_excel('/Users/mycelebs/Desktop/maimovie_kr_data_맵핑_완료.xlsx')

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)], axis = 1, inplace = True)

# %%
movie_list = df['md_name'].to_list()

# %%
movie_list
# Out:
# ['명량',
#  '아바타',
#  '왕의 남자',
#  '괴물',
#  '태극기 휘날리며',
#  '도둑들',
#  '광해 : 왕이 된 남자',
#  '베테랑',
#  '실미도',
#  '국제시장',
#  '암살',
#  '인터스텔라',
#  '7번방의 선물',
#  '겨울왕국',
#  '변호인',
#  '어벤져스: 에이지 오브 울트론',
#  '해운대',
#  '친구',
#  '아이언맨 3',
#  '관상',
#  '설국열차',
#  '공동경비구역 JSA',
#  '쉬리',
#  '웰컴 투 동막골',
#  '과속스캔들',
#  '미션임파서블:고스트프로토콜',
#  '트랜스포머',
#  '검사외전',
#  '국가대표',
#  '트랜스포머: 패자의 역습',
#  '레미제라블',
#  '쌍화점',
#  '어벤져스',
#  '트랜스포머 3',
#  '베를린',
#  '디워',
#  '타짜',
#  '최종병기 활',
#  '다크 나이트 라이즈',
#  '수상한 그녀',
#  '인셉션',
#  '좋은 놈, 나쁜 놈, 이상한 놈',
#  '화려한 휴가',
#  '써니',
#  '타이타닉',
#  '내부자들',
#  '킹스맨 : 시크릿 에이전트',
#  '미녀는 괴로워',
#  '살인의 추억',
#  '반지의 제왕 : 왕의 귀환',
#  '해적: 바다로 간 산적',
#  '아저씨',
#  '반지의 제왕 : 두개의 탑',
#  '히말라야',
#  '엽기적인 그녀',
#  '은밀하게 위대하게',
#  '전우치',
#  '늑대소년',
#  '미션 임파서블: 로그네이션',
#  '추격자',
#  '맘마미아!',
#  '신라의 달밤',
#  '사도',
#  '가문의 영광',
#  '매트릭스2 리로디드',
#  '인사이드 아웃',
#  '동갑내기 과외하기',
#  '해리포터와 마법사의 돌',
#  '미션 임파서블 3',
#  '집으로...',
#  '쿵푸팬더 2',
#  '의형제',
#  '월드 워 Z',
#  '쿵푸 팬더',
#  '말아톤',
#  '사랑과 영혼',
# ...
